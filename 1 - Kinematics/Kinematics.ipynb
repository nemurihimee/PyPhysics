# %% [markdown]
# Unit 1 - Kinematics
#
# All about motion

# %% [markdown]
# Key Concepts
#
# --Frame of Reference
# --Position
# --Scalar
# --Vector
# --Displacement
# --Distance
# --Velocity
# --Speed
# --Acceleration
# --Center of Mass
# --Free Fall
# --Acceleration due to Gravity
# --Projectiles
# --Angled Launches
# --Vector Components

# %% [markdown]
# Key Equations

# %%
import math
from IPython.display import display, Math, Latex

#constant
g = 9.81


#General Formulas


#S = D/t
D = 100   #Distance given
t = 10   #Time given

S = D/t     #Speed calculated
print(S)  

display(math('$\int_a^b f(x) = F(b) - F(a)$)')


#V = x/t
x = 100   #Displacement given 
t = 10   

V = x/t     #Velocity calculated
print(V)    


#Aavg = V/t
V = 10   #Velocity given
t = 10

Aavg = V/t  #Average acceleration calculated
print(Aavg)  


#4 Kinetic Formulas


#Vf = Vi + at
Vi = 5  #Initial velocity given
a = 1   #Acceleration given

Vf = Vi+(a*t) #Final velocity calculated
print(Vf)


#x = Vit + 1/2at^2
Vi = 5  
t = 10
a = 1

x = Vi*t + (1/2)*(a)*(t**2) 
print(x)


#Vf^2 = Vi^2 + 2ax
Vi = 5  
a = 1   
x = 100  

Vf = math.sqrt(Vi**2 + 2*a*x)
print(Vf) 


#x = 1/2 (Vf + Vi)t
Vf = input  #Final Velocity given
Vi = input
t = input

x = (1/2)*(Vf+Vi)*t
print(x)
# Out:
# 10.0
# '$\\int_a^b f(x) = F(b) - F(a)$'
# 10.0
# 1.0
# 15
# 100.0
# 15.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-75b75d33165f> in <module>
#      69 t = input
#      70
# ---> 71 x = (1/2)*(Vf+Vi)*t
#      72 print(x)
#      73
#
# TypeError: unsupported operand type(s) for +: 'method' and 'method'
